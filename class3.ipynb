# %% [markdown]
# # this is the class notes of the class on friday 7th feb
# we are going to do a question in the class which is reagarding the random and normal distribution

# %% [markdown]
# # Question
# A leading medical institution of Jhajjar, Haryana, has 2167 patients of cancer who were given medicines, including steroids and chemotherapy.Of these about 61.3 percent of patients are male.
# After three months of cancer treatment they showed high sugar levels, though the cancer treatment appeared successful. As an aside, the allowed sugar levels is 140. Patients above 140, but below 170 would be considered as pre-diabetic.
# Their fasting sugar levels ranged from 243 to 357 that followed a uniform distribution approximately.
#
# As an intervention, the patients were put on medication to manage sugar levels. After four weeks their fasting sugar levels came somewhat reduced, though still higher than the accepted norm of 140. This was reported to be between 183 and 219, again following uniform distribution.
#
# 1 a) Generate the data points, assuming that each patient responds systematically to medicines. In other words, each patient shows a drop in sugar levels (after taking medicine) compared to his or her earlier levels. Create a dataframe for these patients using appropriate column names.
#
# 1 b) Show the plots for sugar levels before and after the interventions using numpy and matplotlib. Ensure that the plots are readable, understandable and usable for a panel of doctors evaluating the results.
# 1 c) Similarly compare sugar levels for males vs females, before and after
#  V
# 2 a) Generate data points assuming a normal distribution for before and after diabetes treatment medicines.
# 2 b) Show plots for sugar levels comparisons as in 1 b).
# 2 c) Same as in 1 c)

# %% [markdown]
# From the given question we will first note down the important components of information we need which is
# the size and the type of distribution which needs to be followed which will be unifrom distribution

# %% [markdown]
# # what is the need for random data
# It is very messy to collect the actual data
# The need for random data is that we can use it instead of using the

# %%
# begning with importing the necssary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
np.random.seed(1000)
# what this will do that it will given the same random values every time in the code.
np.set_printoptions(precision=0)
patients_size = 2167 # by common method 1e4 genertaes a float but we have to generate an int in the given process.
before_breakfast = np.random.uniform(243 , 357 , patients_size)
before_breakfast
# why we shouldnt use plt plot is that the dataa points in the given 
# in it the x axis has the order of the index.
# Out:
# array([318., 256., 351., ..., 324., 336., 325.])

# %%
# now creating a histogram for the following data
plt.hist(before_breakfast);
# what does historgram is that first it sorts the given array to us and then works upon it.

# %%
plt.boxplot(before_breakfast, vert=False);
# ; this is used to remove the text that comes at the start of the ouput

# %% [markdown]
# >>>>Importance of vert = false is that it will given the output in the vertical form rather than the horizontal form.

# %%
# now we are also going to make a plot for the values of sugar after breakfast
after_medication = np.random.uniform(183 , 219 , patients_size)
after_medication
# Out:
# array([209., 203., 190., ..., 196., 215., 191.])

# %% [markdown]
# we had been given that the values in the after breakfast sho

# %%
# to make a histogram for the after breakfast column
plt.hist(after_medication)
# Out:
# (array([199., 210., 229., 217., 199., 233., 237., 224., 219., 200.]),
#  array([183., 187., 190., 194., 197., 201., 205., 208., 212., 215., 219.]),
#  <BarContainer object of 10 artists>)

# %%
# for making the box plot for the values of the after breakfast
plt.boxplot(after_medication ,vert=False);
# the box plot is a plot which shows the range and values of the give data point which we are finding
# from a presentation point of view box plot is used to give proper representation and visualisation

# %%
plt.boxplot(after_breakfast ,vert=False);
# since we have already defined the seed , the random values will be same all the time

# %% [markdown]
# # now we are going to merge both the plot and show side by side in a comparison mode.

# %%
counts , bin_edges , hist_fig = plt.hist(before_breakfast , bins = int(1e2) , color= 'red' );
counts , bin_edges
plt.title("sugar level before breakfast")
# Out:
# Text(0.5, 1.0, 'sugar level before breakfast')

# %% [markdown]
# In histogram we are able to the see the empty values and the places were the values are not present while in box plot we are not able to see such places.

# %%
plt.figure(figsize=(12,6))

plt.subplot(2, 1, 1)
plt.title("Sugar Levels Before")
plt.axvline(x=sugar_before.mean(), color = 'green', linestyle = '--', linewidth = 0.5, animated = True)
plt.axvline(x=sug_b4_Q1, color = 'green', linestyle = '--', linewidth = 1.5, animated = True)
plt.text(s=f"Q1 : {sug_b4_Q1:,.2f}", x = 0.994*sug_b4_Q1, y = 5)
plt.text(s=f"Q2 : {sug_b4_Q2:,.2f}", x = 0.994*sug_b4_Q2, y = 5)
plt.text(s=f"Q3 : {sug_b4_Q3:,.2f}", x = 0.994*sug_b4_Q3, y = 5)
plt.axvline(x=sug_b4_Q2, color = 'red', linestyle = '--', linewidth = 1.5, animated = True)
plt.axvline(x=sug_b4_Q3, color = 'green', linestyle = '--', linewidth = 1.5, animated = True)

plt.hist(sugar_before, bins=size)
# plt.xlim(180,360)


plt.subplot(2,1,2)
plt.axvline(x=sugar_before.mean(), color = 'green', linestyle = '--', linewidth = 0.5, animated = True)
plt.axvline(x=sug_b4_Q1, color = 'red', linestyle = '--', linewidth = 1.5, animated = True)
# plt.text(s=f"Q1 : {sug_b4_Q1:,.2f}", x = 0.994*sug_b4_Q1, y = 20)
# plt.text(s=f"Q2 : {sug_b4_Q2:,.2f}", x = 0.994*sug_b4_Q2, y = 20)
# plt.text(s=f"Q3 : {sug_b4_Q3:,.2f}", x = 0.994*sug_b4_Q3, y = 20)
plt.axvline(x=sug_b4_Q2, color = 'green', linestyle = '--', linewidth = 1.5, animated = True)
plt.axvline(x=sug_b4_Q3, color = 'blue', linestyle = '--', linewidth = 1.5, animated = True)
plt.boxplot(sugar_before,orientation='horizontal',showmeans=True, meanline = False)
# plt.xlim(180,360)


# plt.yticks(fontsize=8)
# plt.xticks(fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 plt.subplot(2, 1, 1)
#       4 plt.title("Sugar Levels Before")
# ----> 5 plt.axvline(x=sugar_before.mean(), color = 'green', linestyle = '--', linewidth = 0.5, animated = True)
#       6 plt.axvline(x=sug_b4_Q1, color = 'green', linestyle = '--', linewidth = 1.5, animated = True)
#       7 plt.text(s=f"Q1 : {sug_b4_Q1:,.2f}", x = 0.994*sug_b4_Q1, y = 5)
#
# NameError: name 'sugar_before' is not defined
